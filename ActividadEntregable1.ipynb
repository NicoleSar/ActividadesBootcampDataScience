# %% [markdown]
# ## Caso práctico: Brewery Operations and Market Analysis Dataset
#
# ### About Dataset
# *Overview*
#
# This dataset presents real-world brewing records from Arbor Brewing Company, a renowned craft brewery in Bangalore, India, covering January 2020 to December 2020. It offers a comprehensive view of brewing parameters, quality assessments, sales trends, and operational efficiency—crucial for optimizing brewing processes and market strategies.
#
# *Content*
#
# 1. Brewing Parameters
# - Fermentation Time (days) – Duration of fermentation for each batch.
# - Temperature (°C) – Fermentation temperature.
# - pH Level – Acidity measurement affecting beer flavor and stability.
# - Gravity – Indicator of fermentation progress.
# - Alcohol Content (% ABV) – Alcohol percentage per batch.
# - Bitterness (IBU) – Measurement of hop bitterness.
# - Color (EBC) – Beer color intensity based on the European Brewery Convention scale.
# - Ingredient Ratio – Composition of raw materials in each batch.
#
# 2. Beer Styles & Packaging
# - Beer Styles – Includes IPA, Lager, Stout, Pilsner, and Wheat Beer.
# - SKU (Stock Keeping Unit) – Packaging formats: Pints, Bottles, Cans, Kegs.
# - Location – Sales across different regions in Bangalore.
#
# 3. Sales & Quality Metrics
# - Volume Produced (liters) – Batch-wise beer production.
# - Total Sales (INR) – Revenue generated per batch.
# - Quality Score – Sensory evaluation rating for each batch.
#
# 4. Efficiency & Loss Metrics
# - Brewhouse Efficiency (%) – Indicator of brewing system efficiency.
# - Losses at Various Stages:
# - Brewing Loss (%) – Losses due to raw material inefficiencies.
# - Fermentation Loss (%) – Yield reduction during fermentation.
# - Bottling/Kegging Loss (%) – Losses occurring during final packaging.
#
# *Applications*
#
# 📌 Brewing Process Optimization – Identifying brewing conditions that improve beer quality.
# 📌 Market Analysis – Analyzing sales trends based on beer styles and packaging choices.
# 📌 Supply Chain Optimization – Reducing brewing and packaging losses to improve profitability.
# 📌 Quality Control – Evaluating the impact of brewing parameters on final product consistency.

# %%
#Import libraries 
import pandas as pd

# %%
#Charge dataset: Brewery Operations and Market Analysis Dataset
BreweryOp = pd.read_csv('C:/Users/THINKBOOK/Documents/1. ESTUDIOS y FORMACIONES/1. BOOTCAMP DATA SCIENCE/Desarrollos de las clases/Clase 5- Lectura y Manipulación de archivos con Pandas/Datasets/brewery_data.csv')
BreweryOp.head() # show the 5 first registers
# Out:
#    Batch_ID   Brew_Date  Beer_Style      SKU      Location  Fermentation_Time  \
# 0    174131  2020-01-01       Lager    Pints    Whitefield                 23
# 1    174132  2020-01-01       Lager  Bottles     Yelahanka                 24
# 2    174133  2020-01-01         IPA     Kegs     Yelahanka                  7
# 3    174134  2020-01-02  Wheat Beer     Cans   Indiranagar                 10
# 4    174135  2020-01-02     Pilsner  Bottles  Marathahalli                 19
#
#    Temperature  pH_Level  Gravity  Alcohol_Content  Bitterness  Color  \
# 0         13.7      4.79    1.199              5.1          16      8
# 1         12.8      4.29    1.201              5.0          28     10
# 2         18.3      4.61    1.255              6.8          49     14
# 3         19.5      4.87    1.195              4.7          26      5
# 4          8.0      4.40    1.183              4.3          20     11
#
#   Ingredient_Ratio  Volume_Produced  Total_Sales  Quality_Score  \
# ...

# %% [markdown]
# ### Exploratory analysis

# %%
#Observe dataset configuration (rows, columns)
BreweryOp.shape
# Out:
# (583, 20)

# %%
#Rename column 'Location'
BreweryOp = BreweryOp.rename(columns={'Location':'Indian city'}) 
BreweryOp.head()
# Out:
#    Batch_ID   Brew_Date  Beer_Style      SKU   Indian city  Fermentation_Time  \
# 0    174131  2020-01-01       Lager    Pints    Whitefield                 23
# 1    174132  2020-01-01       Lager  Bottles     Yelahanka                 24
# 2    174133  2020-01-01         IPA     Kegs     Yelahanka                  7
# 3    174134  2020-01-02  Wheat Beer     Cans   Indiranagar                 10
# 4    174135  2020-01-02     Pilsner  Bottles  Marathahalli                 19
#
#    Temperature  pH_Level  Gravity  Alcohol_Content  Bitterness  Color  \
# 0         13.7      4.79    1.199              5.1          16      8
# 1         12.8      4.29    1.201              5.0          28     10
# 2         18.3      4.61    1.255              6.8          49     14
# 3         19.5      4.87    1.195              4.7          26      5
# 4          8.0      4.40    1.183              4.3          20     11
#
#   Ingredient_Ratio  Volume_Produced  Total_Sales  Quality_Score  \
# ...

# %%
#Descriptive statistics 
BreweryOp.describe()
# Out:
#             Batch_ID  Fermentation_Time  Temperature    pH_Level     Gravity  \
# count     583.000000         583.000000   583.000000  583.000000  583.000000
# mean   174422.000000          13.210978    17.768439    4.391132    1.227285
# std       168.441879           5.547832     4.009070    0.429886    0.036009
# min    174131.000000           7.000000     8.000000    3.200000    1.161000
# 25%    174276.500000           9.000000    14.250000    4.220000    1.198500
# 50%    174422.000000          11.000000    19.000000    4.450000    1.222000
# 75%    174567.500000          18.500000    20.550000    4.670000    1.254000
# max    174713.000000          26.000000    25.000000    5.430000    1.320000
#
#        Alcohol_Content  Bitterness       Color  Volume_Produced   Total_Sales  \
# count       583.000000  583.000000  583.000000       583.000000    583.000000
# mean          5.563808   34.626072   11.626072      2730.365352  14859.661098
# ...

# %%
#Count by SKU category: presentation forms (kegs, bottles, pints, cans) 
BreweryOp['SKU'].value_counts()
# Out:
# SKU
# Pints      155
# Bottles    149
# Cans       143
# Kegs       136
# Name: count, dtype: int64

# %%
#Simple filter: filter lager beer data
BreweryOp[BreweryOp ['Beer_Style'] == 'Lager']

#Multiple filter: filter SKU Kegs lager beer data (kegs format)
BreweryOp[(BreweryOp ['Beer_Style'] == 'Lager') & (BreweryOp ['SKU'] == 'Kegs')]
#Multiple filter: filter SKU Kegs lager beer data (kegs format) with a quality score greater than 9.0
BreweryOp[(BreweryOp ['Beer_Style'] == 'Lager') & (BreweryOp ['SKU'] == 'Kegs') & (BreweryOp ['Quality_Score'] >= 9.0)]
#Multiple filter: filter SKU Kegs lager beer data (kegs format) with a quality score greater than 9.0 and Bottling/Kegging Loss (%) lower than 2.0
BreweryOp[(BreweryOp ['Beer_Style'] == 'Lager') & (BreweryOp ['SKU'] == 'Kegs') & (BreweryOp ['Quality_Score'] >= 9.0) & (BreweryOp ['Loss_During_Bottling_Kegging'] <= 2.0)]

#Creating a new dataset applying previous filters 
BreweryOpLagerKegs = BreweryOp[(BreweryOp ['Beer_Style'] == 'Lager') & (BreweryOp ['SKU'] == 'Kegs') & (BreweryOp ['Quality_Score'] >= 9.0) & (BreweryOp ['Loss_During_Bottling_Kegging'] <= 2.0)]
BreweryOpLagerKegs.head()
# Out:
#      Batch_ID   Brew_Date Beer_Style   SKU      Indian city  \
# 142    174273  2020-04-08      Lager  Kegs  Electronic City
# 358    174489  2020-08-12      Lager  Kegs       Whitefield
#
#      Fermentation_Time  Temperature  pH_Level  Gravity  Alcohol_Content  \
# 142                 20         11.8      4.23    1.178              4.2
# 358                 21         13.7      4.90    1.173              4.3
#
#      Bitterness  Color Ingredient_Ratio  Volume_Produced  Total_Sales  \
# 142          16     10       1:0.3:0.28             1928     13036.81
# 358          16     11      1:0.21:0.19             4353     20370.40
#
#      Quality_Score  Brewhouse_Efficiency  Loss_During_Brewing  \
# 142           10.0             75.727952                  3.8
# 358            9.4             79.698986                  2.1
#
#      Loss_During_Fermentation  Loss_During_Bottling_Kegging
# 142                       5.8                           1.5
# ...

# %%
#Personalize dataset order 
BreweryOp.sort_values(by = 'Quality_Score', ascending = False)
# Out:
#      Batch_ID   Brew_Date Beer_Style      SKU      Indian city  \
# 106    174237  2020-03-13       Sour    Pints      Malleswaram
# 104    174235  2020-03-09     Porter     Kegs        Yelahanka
# 213    174344  2020-05-22    Pilsner    Pints     Marathahalli
# 107    174238  2020-03-14    Pilsner     Kegs  Electronic City
# 182    174313  2020-05-05        Ale  Bottles        Jayanagar
# ..        ...         ...        ...      ...              ...
# 502    174633  2020-11-07      Lager     Kegs       HSR Layout
# 539    174670  2020-12-04      Stout     Cans     Marathahalli
# 574    174705  2020-12-25        IPA     Kegs      Malleswaram
# 496    174627  2020-11-03       Sour     Cans      Indiranagar
# 542    174673  2020-12-07       Sour    Pints        Jayanagar
#
#      Fermentation_Time  Temperature  pH_Level  Gravity  Alcohol_Content  \
# 106                  8         19.0      3.58    1.186              4.9
# ...

# %%
#Creating a new data set applying a new order of original data
BreweryOp_V2 = BreweryOp[['Beer_Style','SKU','Alcohol_Content','Total_Sales','Quality_Score']]
BreweryOp_V2
# Out:
#      Beer_Style      SKU  Alcohol_Content  Total_Sales  Quality_Score
# 0         Lager    Pints              5.1     13636.33            9.8
# 1         Lager  Bottles              5.0      9312.37            9.7
# 2           IPA     Kegs              6.8      5975.79            9.8
# 3    Wheat Beer     Cans              4.7     17518.47            9.9
# 4       Pilsner  Bottles              4.3      9883.15            9.8
# ..          ...      ...              ...          ...            ...
# 578      Porter     Kegs              6.8     11547.15            8.9
# 579         IPA  Bottles              6.5      8063.57            9.0
# 580       Lager    Pints              5.1     16925.73           10.0
# 581         IPA  Bottles              6.4     10278.13           10.0
# 582       Lager     Kegs              4.9     12173.03            8.6
#
# [583 rows x 5 columns]

# %%
# Basic Data Visualization: Visualize Total_Sales by SKU beer
BreweryOp.boxplot(column = 'Total_Sales', by = 'SKU')
# Out:
# <Axes: title={'center': 'Total_Sales'}, xlabel='SKU'>

# %%
import seaborn as sns 
sns.boxplot(data = BreweryOp, x = 'SKU', y = 'Total_Sales', showmeans = True)
# Out:
# <Axes: xlabel='SKU', ylabel='Total_Sales'>
